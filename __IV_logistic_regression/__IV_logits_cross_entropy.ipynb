# %% [markdown]
# # Logits and cross entropy
#
# We will go throug this term to understand how they relate to the concepts we discussed previously. <code>**Logits**</code> is a very commonly used in deep learning jargon and it is probably inspired by the logits for logistic regression
#
#  - In deep learning, the <code>**logits**</code> are the <code>**net inputs**</code> of the last neuron layer
#  - In statistics we call the <code>**log-odds**</code> the logits
#  - In logistic regression the logits are naturally 𝐰⊤𝐱 because the log-odds is just short for "logorithm of the odds": log(p / (1 - p))
#  - In other words, the logits are te inverse of the logistic sigmoid function

# %%
# %run ../code_examples/visualize/logit_function.py

# %% [markdown]
# ## Binary cross entropy
#
#  - Negative log-likelihood and binary corss entropy are equivalent
#  - They are just formulated in different contexts
#  - Cross entropy comes from the information theory in computer science perspective
#  - For those who took statistics class or machine learning class have seen entropy (not cross entropy though) in the context of a decision tress (but wit log2 instead of naturla log)
